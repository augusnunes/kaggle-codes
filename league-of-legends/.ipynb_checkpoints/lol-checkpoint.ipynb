# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.listdir()
# Out:
# ['SILVER-IV-1.csv',
#  'lol.ipynb',
#  '.ipynb_checkpoints',
#  'final_data.csv',
#  'final_data2.csv',
#  'SILVER-IV-0.csv',
#  'features.md',
#  'league_matches_silverIV.csv',
#  'get-data.py',
#  'final_data1.csv',
#  'get-data2.py']

# %%
df = pd.read_csv("league_matches_silverIV.csv")
df.head()
# Out:
#    match_duration team_win  blue_team_barons  blue_team_heralds  \
# 0            1452     blue                 0                  2
# 1            1458     blue                 0                  2
# 2            2326     blue                 1                  1
# 3            2229      red                 0                  1
# 4            2592      red                 2                  0
#
#    blue_team_dragons  blue_team_towers  blue_team_inhibitors  blue_team_kills  \
# 0                  2                11                     3               37
# 1                  4                11                     3               36
# 2                  2                 9                     3               50
# 3                  3                 8                     1               29
# 4                  2                 5                     0               24
#
#    blue_team_assists  blue_team_deaths  ...  red_team_damage_self_mitigated  \
# ...

# %%
df.loc[:, 'match_duration'] /= 60

# %%
df.shape
# Out:
# (3785, 42)

# %%
df
# Out:
#       match_duration team_win  blue_team_barons  blue_team_heralds  \
# 0          24.200000     blue                 0                  2
# 1          24.300000     blue                 0                  2
# 2          38.766667     blue                 1                  1
# 3          37.150000      red                 0                  1
# 4          43.200000      red                 2                  0
# ...              ...      ...               ...                ...
# 3780       33.033333      red                 0                  1
# 3781       47.833333     blue                 1                  0
# 3782       18.083333     blue                 0                  1
# 3783       35.116667     blue                 1                  2
# 3784       32.266667     blue                 1                  1
#
#       blue_team_dragons  blue_team_towers  blue_team_inhibitors  \
# 0                     2                11                     3
# ...

# %% [markdown]
# # Análise expo

# %%
# Cor vermelha
red_c = "#db1d23"
# Cor azul
blue_c = "#1d5cdb"

# %%
columns_blue = list(df.filter(regex="blue_*").columns)
columns_blue.append('match_duration')

df_blue = df[df.team_win == 'blue'].loc[:, columns_blue]

# %%
columns_red = list(df.filter(regex="red_*").columns)
columns_red.append('match_duration')

df_red = df[df.team_win == 'red'].loc[:, columns_red]

# %%
sns.displot(data=df,x='match_duration', hue='team_win', kind='kde', palette = [blue_c, red_c])

# %%
df.match_duration[df.match_duration >=50].value_counts().sum()
# Out:
# 20

# %% [markdown]
# 20 jogos com uma duração maior/igual que 50 minutos

# %%
out_data = df[df.match_duration >=50]
sns.displot(out_data, x='team_win')

# %%
sns.displot(df, x='team_win')

# %%
sns.heatmap(df.corr())

# %%
colunas = list(df.columns)
del colunas[1]

# %%
for i in colunas:
    sns.displot(data=df,x=i, hue='team_win', kind='kde', palette = [blue_c, red_c])
# Out:
# /home/augusto/.local/lib/python3.8/site-packages/seaborn/axisgrid.py:392: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /home/augusto/.local/lib/python3.8/site-packages/seaborn/axisgrid.py:392: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# ...
